# %% [markdown]
# ## <font size=4> *Métodos Numéricos II*, 2025 - </font> <font size=3 color='gray'> Alan Reyes-Figueroa </font>
# # <center> <font size=8> **Normas Matriciales** </font> </center>

# %%
import numpy as np
import scipy as sp

# %% [markdown]
# ### Cálculo de normas

# %%
A = np.array([[1, 2, 3], [0, -3, 1]])

# %%
print(A)
# Out:
# [[ 1  2  3]
#  [ 0 -3  1]]

# %%
A.shape
# Out:
# (2, 3)

# %%
np.linalg.norm(A)     # por default calcula la norma de Frobenius
# Out:
# 4.898979485566356

# %%
np.linalg.norm(A, 'fro')
# Out:
# 4.898979485566356

# %%
np.linalg.norm(A, 1)   # norma 1
# Out:
# 5.0

# %%
np.linalg.norm(A, 2)   # norma 2
# Out:
# 3.950386218518892

# %%
np.linalg.norm(A, np.inf)
# Out:
# 6.0

# %% [markdown]
# ### Norma -1 = min de las $||a_i||_1$

# %%
np.linalg.norm(A, -1)
# Out:
# 1.0

# %% [markdown]
# ### Norma $-\infty$ = min de las $||a_i^T||_1$

# %%
np.linalg.norm(A, -np.inf)
# Out:
# 4.0
